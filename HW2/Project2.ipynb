# %% [markdown]
# <a href="https://colab.research.google.com/github/Rtniewi/cwiertniewicz-DataScience/blob/main/HW2/Project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ///*** Katrina Cwiertniewicz
# //*** Introduction to Data Science IS1
# //***9/10/2025
# //*** Project 2
# ###The purpose of this assignment is to analyze and clean the data sets USArrests and Child Mortality Rates using Excel and SQL.

# %% [markdown]
# ## **Problem 1**

# %% [markdown]
# # **Excel**

# %% [markdown]
# **A. Address all the missing values.**

# %% [markdown]
# Georgia has a missing value for Assault. This value was replaced by the average of all values.

# %% [markdown]
# **B. Look for outliers and smooth noisy data, if any.**

# %% [markdown]
# *  North Dakota has a Murder rate of 0.8, which would not be an accurate representation for a single murder. This is a potential error and has been changed to 1.
#
#
# *  Wisconsin seems like an outlier, but it does correlate with Assaults and Murders, both being low. In this case, I think the data is accurate
#
#
# * The values for murders should be represented using a whole number. Data Reduction was used to round the Murder column to more accurately represent the murder rate.

# %% [markdown]
# **C. Plot Murder rates for all 50 states**

# %% [markdown]
# ![Screenshot 2025-09-08 162622.png](data:image/png;base64,...)

# %% [markdown]
# **D. Plot histogram of assaults**

# %% [markdown]
# ![Screenshot 2025-09-08 162800.png](data:image/png;base64,...)

# %% [markdown]
# **E. Plot Murder rate vs. Assault rate.**

# %% [markdown]
# ![Screenshot 2025-09-08 162813.png](data:image/png;base64,...)

# %% [markdown]
# **F. Prepare the dataset to establish a relation between an urban population category and a crime type. Hint: Convert the urban population percentage into categories, for example, small (<50%), medium (<60%), large (<70%), and extra-large (70% and above) urban population.**

# %% [markdown]
# Data discretization is used to categorize the urban population category by size using a number categorization of 1 through 4. Higher numbers equal a higher urban population.

# %% [markdown]
# ![Screenshot 2025-09-08 163111.png](data:image/png;base64,...)

# %% [markdown]
# # **SQL**

# %% [markdown]
# **B. Use SQL to replace all missing values in a column by the average.
# Hint: Use the Update command.**
# ![Screenshot 2025-09-08 161227.png](data:image/png;base64,...)

# %% [markdown]
# **C. Find min, max, mean, and variance of all numeric attributes in SQL.**

# %% [markdown]
# ![Screenshot 2025-09-21 130116.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-09-21 130132.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **D. Use SQL to answer the following questions:**

# %% [markdown]
# **-- Which state has the maximum murder rate?**

# %% [markdown]
# ![Screenshot 2025-09-08 161023.png](data:image/png;base64,...)

# %% [markdown]
# **-- List of states in ascending order of urban population percentages.**

# %% [markdown]
# ![Screenshot 2025-09-08 161007.png](data:image/png;base64,...)

# %% [markdown]
# **-- How many states have higher murder rates than Arizona? List those states.**

# %% [markdown]
# ![Screenshot 2025-09-08 160930.png](data:image/png;base64,...)

# %% [markdown]
# # Conclusion
# After analyzing the data, there is a correlation between Murder and Assault rates. If we see a larger number of Assaults in a State, we will most likely see a larger Murder rate. When comparing Urban Population Category Size, a larger Urban Population does not inherently mean larger Murder or Assault rates. Most states are fairly spaced out regardless of their Urban Population Size when plotting the Assault and Murder Rates.

# %% [markdown]
# # **Problem 2**

# %% [markdown]
# # **Excel**

# %% [markdown]
# **A. Address all the missing values using the techniques at you disposal**

# %% [markdown]
# The child mortality txt file was converted to a csv file. Comma delimiters were added to separate columns. "??" values were changed to null so they are more readable for different systems.

# %% [markdown]
# To resolve the null values, instead of using the average, I used the mean of the values above and below each null data point. This was because each column's value steadily declined. If I were to use the average, the values would create outliers in the data instead of following the downward slope.

# %% [markdown]
# **B. Prepare the dataset to establish the following relations:**

# %% [markdown]
# Below are graphs representing the data with missing values addressed and the values converted to the likert scale.

# %% [markdown]
# **Under-five Mortality Rate and Neonatal Mortality Rate**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Infant Mortality Rate and Noenatal Mortality Rate**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Year and Infant Mortality Rate**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**SQL**

# %% [markdown]
# **C. Answer the following queries in SQL:**

# %% [markdown]
# **-- Display the entire table.**

# %% [markdown]
# ![Screenshot 2025-09-21 125211.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-09-21 125230.png](data:image/png;base64,...)

# %% [markdown]
# **-- Which years have the lowest and highest infant mortality years, respectively?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **-- In what years the neonatal mortality rates were above average?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **-- Display the sorted infant mortality rates in descending order.**

# %% [markdown]
# ![Screenshot 2025-09-16 131142.png](data:image/png;base64,...)

# %% [markdown]
# **-- Display min, max, mean, variance, and standard deviation for each mortality rate.**

# %% [markdown]
# ![Screenshot 2025-09-21 125351.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-09-16 132640.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-09-16 132704.png](data:image/png;base64,...)

# %% [markdown]
# **-- Add a new column called Above-Five Mortality Rate and populate it with appropriate values. Hint: Use Alter Table Add Column.**

# %% [markdown]
# The above-five mortality rate was determined by finding the difference between the rate of change of each value column. I assumed that the rate would continue to increase to predict the values.

# %% [markdown]
# ![Screenshot 2025-09-16 133036.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-09-16 132959.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-09-16 133019.png](data:image/png;base64,...)

# %% [markdown]
# # Conclusion
#
# After analyzing the data, there is a downward slope when comparing all mortality rates with years. Mortality rates continue to decline as the years continue, indicating that multiple factors may be contributing to a decrease in the overall child mortality rate. We should expect these rates to continue to decline and can predict an improvement in child mortality rates in future years.
