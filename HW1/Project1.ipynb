# %% [markdown]
# <a href="https://colab.research.google.com/github/Rtniewi/cwiertniewicz-IDS/blob/main/HW1/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ///*** Katrina Cwiertniewicz
# //*** Introduction to Data Science IS1
# //*** 8/27/2025
# //*** Project 1
# ###The purpose of this assignment is to analyze data sets using the functions min, mean, max, and sum in google sheets.

# %% [markdown]
# # Problem 1

# %% [markdown]
# ![Screenshot 2025-08-27 143408.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-08-27 155926.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-08-27 142542.png](data:image/png;base64,...)

# %% [markdown]
# **Based on the chicken feed data, which type of chicken food appears the most beneficial for a thriving poultry business? Explain your answer.**

# %% [markdown]
# Sunflower feed appears to be the most beneficial for a thriving poultry business. It has the highest sum, minimum, mean, and maximum chicken weight compared to the other feeds. Casein is similar in mean weight; however, due to it being lower in minimum and maximum weight compared to the Sunflower feed, it will not surpass the Sunflower seed in higher weight per chicken.

# %% [markdown]
# # Problem 2

# %% [markdown]
# ![Screenshot 2025-08-27 155838.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-08-27 155904.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-08-27 155856.png](data:image/png;base64,...)

# %% [markdown]
# **If you had to choose an auto insurance provider based on these ratings, which one would you opt for? Explain your answer**

# %% [markdown]
# I would choose Progressive as an auto insurance provider because its mean rating is higher when compared with the other insurance providers. GECIO has a higher max rating and is also close in mean and sum of ratings when compared with Progressive. However, I think the mean rating is more accurate to determine the better auto company. Regardless, there are only three ratings for each insurance provider, which gives us only a small amount of data to work with. If we had more data, we might see a bigger rating difference between GEICO and Progressive.
